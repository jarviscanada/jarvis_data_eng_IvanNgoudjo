# %% [markdown]
# **ETL Bookings**

# %%
from pyspark.sql.types import StructType, StructField, IntegerType, TimestampType

file_location = "/Volumes/training/training_data/training_volume/bookings.csv" 

# Here is the solution to define schema manually
# Define schema for the bookings table
schema_bookings  = StructType([
    StructField("bookid", IntegerType(), True),
    StructField("facid", IntegerType(), True),
    StructField("memid", IntegerType(), True),
    StructField("starttime", TimestampType(), True),
    StructField("slots", IntegerType(), True)
])

# Read data from CSV file into DataFrame with predefined schema
df = spark.read.format("csv").option("header", "true").schema(schema_bookings).load(file_location)

# No 

# Drop the table if it already exists
spark.sql("DROP TABLE IF EXISTS bookings")

# Write data from DataFrame into managed table
df.write.mode("overwrite").saveAsTable("bookings")

# %% [markdown]
# **ETL Facilities**

# %%
from pyspark.sql.types import StructType, StructField, IntegerType, TimestampType

file_location = "/Volumes/training/training_data/training_volume/facilities.csv" 

# Define schema for the bookings table
schema_facilities = StructType([
    StructField("bookid", IntegerType(), True),
    StructField("facid", IntegerType(), True),
    StructField("memid", IntegerType(), True),
    StructField("starttime", TimestampType(), True),
    StructField("slots", IntegerType(), True)
])

# Read data from CSV file into DataFrame with predefined schema
df = spark.read.format("csv").option("header", "true").schema(schema_facilities).load(file_location)

# No 

# Drop the table if it already exists
spark.sql("DROP TABLE IF EXISTS bookings")

# Write data from DataFrame into managed table
df.write.mode("overwrite").saveAsTable("facilities")

# %% [markdown]
# **ETL Members**

# %%
from pyspark.sql.types import StructType, StructField, IntegerType, TimestampType

file_location = "/Volumes/training/training_data/training_volume/members.csv" 

# Define schema for the bookings table
schema_members = StructType([
    StructField("bookid", IntegerType(), True),
    StructField("facid", IntegerType(), True),
    StructField("memid", IntegerType(), True),
    StructField("starttime", TimestampType(), True),
    StructField("slots", IntegerType(), True)
])

# Read data from CSV file into DataFrame with predefined schema
df = spark.read.format("csv").option("header", "true").schema(schema_members).load(file_location)

# No 

# Drop the table if it already exists
spark.sql("DROP TABLE IF EXISTS bookings")

# Write data from DataFrame into managed table
df.write.mode("overwrite").saveAsTable("members")
